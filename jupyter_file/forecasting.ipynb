# %%
import numpy as np
import pandas as pd
import glob
import matplotlib.pyplot as plt

# %% [markdown]
# # Loading Data

# %%
path_dataset = "../dataset/PM2.5/"
# load all files
all_files = glob.glob(path_dataset + "/*.xlsx")

# %%
all_files = sorted(all_files)
all_files
# Out:
# ['../dataset/PM2.5/PM2.5(2011).xlsx',
#  '../dataset/PM2.5/PM2.5(2012).xlsx',
#  '../dataset/PM2.5/PM2.5(2013).xlsx',
#  '../dataset/PM2.5/PM2.5(2014).xlsx',
#  '../dataset/PM2.5/PM2.5(2015).xlsx',
#  '../dataset/PM2.5/PM2.5(2016).xlsx',
#  '../dataset/PM2.5/PM2.5(2017).xlsx',
#  '../dataset/PM2.5/PM2.5(2018).xlsx',
#  '../dataset/PM2.5/PM2.5(2019).xlsx',
#  '../dataset/PM2.5/PM2.5(2020).xlsx',
#  '../dataset/PM2.5/PM2.5(2021).xlsx',
#  '../dataset/PM2.5/PM2.5(2022).xlsx',
#  '../dataset/PM2.5/PM2.5(2023).xlsx']

# %%
xls = pd.ExcelFile(all_files[0])
test_df = pd.read_excel(xls, 'PM2.5')

# %%
test_df
# Out:
#                     Date                54T   36T   30T
# 0    2011-01-01 00:00:00                NaN   NaN   NaN
# 1    2011-01-02 00:00:00                NaN   NaN   NaN
# 2    2011-01-03 00:00:00                NaN   NaN   NaN
# 3    2011-01-04 00:00:00                NaN   NaN   NaN
# 4    2011-01-05 00:00:00                NaN   NaN   NaN
# ..                   ...                ...   ...   ...
# 363  2011-12-30 00:00:00                NaN  22.0  26.0
# 364  2011-12-31 00:00:00                NaN  21.0  25.0
# 365                  NaN                NaN   NaN   NaN
# 366                  NaN                NaN   NaN   NaN
# 367            หมายเหตุ   N/A : ไม่มีข้อมูล   NaN   NaN
#
# [368 rows x 4 columns]

# %% [markdown]
# # Pre-processing Data

# %%
# Create an empty dataframe for waiting for the concatenation
merged_df = pd.DataFrame(columns=['Date', '36T'])
for file_name in all_files:
   xls = pd.ExcelFile(file_name)
   df = pd.read_excel(xls, 'PM2.5')
   # Drop every row following Date containing NaN
   df = df.dropna(subset=['Date'])
   # Keep only Date and 36T Column
   try:
       df = df[['Date', '36T']]
   except:
       df = df[['Date', '36T ']]
       # rename the column form '36T ' to '36T'
       df = df.rename(columns={'36T ': '36T'})

   # Convert Date to datetime, if some rows are not in the right format, drop them
   try:
       # Drop last row, then convert to datetime
       df = df[:-1]
       df['Date'] = pd.to_datetime(df['Date'])
   except:
       df['Date'] = pd.to_datetime(df['Date'])
   # Concatenate the dataframe
   merged_df = pd.concat([merged_df, df], axis=0)
# reset index
merged_df = merged_df.reset_index(drop=True)
merged_df
# Out:
# /tmp/ipykernel_44602/4178759202.py:24: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   merged_df = pd.concat([merged_df, df], axis=0)
#            Date   36T
# 0    2011-01-01   NaN
# 1    2011-01-02   NaN
# 2    2011-01-03   NaN
# 3    2011-01-04   NaN
# 4    2011-01-05   NaN
# ...         ...   ...
# 4742 2023-12-27  28.7
# 4743 2023-12-28  29.8
# 4744 2023-12-29  23.2
# 4745 2023-12-30  20.2
# 4746 2023-12-31  21.1
#
# [4747 rows x 2 columns]

# %% [markdown]
# # Manipulating Data

# %%
# Plot the data
plt.figure(figsize=(10,5))
plt.plot(merged_df['Date'], merged_df['36T'])
plt.show()

# %%
# Replace the NaN values by the mean of the column
mean_df_copy = merged_df.copy()
mean_df_copy['36T'] = mean_df_copy['36T'].fillna(mean_df_copy['36T'].mean())
plt.figure(figsize=(10,5))
plt.figure(figsize=(10,5))
plt.plot(mean_df_copy['Date'], mean_df_copy['36T'])
plt.show()

# %%
# Replace the NaN values by random values in the range 1 to the mean by each row
random_df_copy = merged_df.copy()
mean_value = random_df_copy['36T'].mean()
random_values = pd.Series(np.random.randint(1, mean_value + 1, size=len(random_df_copy)), index=random_df_copy.index)
random_df_copy['36T'] = random_df_copy['36T'].fillna(random_values)

plt.figure(figsize=(10, 5))
plt.plot(random_df_copy['Date'], random_df_copy['36T'])
plt.show()

# %%
# Replace the NaN values with range 1 to 30
random_df_copy2 = merged_df.copy()
min_ = 1
max_ = 20
random_values = pd.Series(np.random.randint(min_, max_+1, size=len(random_df_copy2)), index=random_df_copy2.index)
random_df_copy2['36T'] = random_df_copy2['36T'].fillna(random_values)

plt.figure(figsize=(10, 5))
plt.plot(random_df_copy2['Date'], random_df_copy2['36T'])
plt.show()

# %% [markdown]
# # Decomposing Data

# %%
from statsmodels.tsa.seasonal import seasonal_decompose


# Decompose the data
decomposed = seasonal_decompose(random_df_copy2['36T'], model='additive', period=365)
# Plot the decomposed components
fig, (ax1, ax2, ax3, ax4) = plt.subplots(4, 1, figsize=(10, 10))
decomposed.observed.plot(ax=ax1)
ax1.set_ylabel('Observed')
decomposed.trend.plot(ax=ax2)
ax2.set_ylabel('Trend')
decomposed.seasonal.plot(ax=ax3)
ax3.set_ylabel('Seasonal')
decomposed.resid.plot(ax=ax4)
ax4.set_ylabel('Residual')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Splitting Data

# %%
# display last rows of the dataframe
random_df_copy2.tail()
# Out:
#            Date   36T
# 4742 2023-12-27  28.7
# 4743 2023-12-28  29.8
# 4744 2023-12-29  23.2
# 4745 2023-12-30  20.2
# 4746 2023-12-31  21.1

# %%
# Split the data into train and test, by 2011-2021 being the train and 2022-2023 the test
train = random_df_copy2[random_df_copy2['Date'].dt.year < 2022]
test = random_df_copy2[random_df_copy2['Date'].dt.year >= 2022]

# %% [markdown]
# # Model Building

# %% [markdown]
# ## ARIMA Model

# %%
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error

# Fit the model

model = ARIMA(train['36T'])
model_fit = model.fit()

# Make predictions
predictions = model_fit.forecast(steps=len(test))
# Calculate the error
error = mean_squared_error(test['36T'], predictions)
error
# Out:
# 768.0586818632654

# %%
# predict on test then plot
plt.figure(figsize=(10,5))
plt.plot(train['Date'], train['36T'], label='Train')
plt.plot(test['Date'], test['36T'], label='Test')
plt.plot(test['Date'], predictions, label='Predictions')
plt.legend()
plt.show()

# %% [markdown]
# ## LSTM Model

# %%
train.shape, test.shape
# Out:
# ((4017, 2), (730, 2))

# %%
# # Set time lag for prediction
# This code work on correct x1, x2, x3, ... x30 to predict x31, x32, x33, ... x60
next_t = 30
# Training data
X_train = []
y_train = []
for i in range(len(train) - next_t):
   X_train.append(train['36T'].values[i:i+next_t])
   y_train.append(train['36T'].values[i+1:i+next_t+1])
X_train = np.array(X_train)
y_train = np.array(y_train)
# Testing data
X_test = []
y_test = []
for i in range(len(test) - next_t):
   X_test.append(test['36T'].values[i:i+next_t])
   y_test.append(test['36T'].values[i+1:i+next_t+1])
X_test = np.array(X_test)
y_test = np.array(y_test)
# reshape the data
X_train = X_train.reshape(-1, next_t, 1)
y_train = y_train.reshape(-1, next_t, 1)
X_test = X_test.reshape(-1, next_t, 1)
y_test = y_test.reshape(-1, next_t, 1)
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((3987, 30, 1), (3987, 30, 1), (700, 30, 1), (700, 30, 1))

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

# Define the model architecture
model = Sequential()
model.add(LSTM(64, input_shape=(next_t, 1), return_sequences=True))
model.add(Dense(1, activation='relu'))  # Moved activation parameter inside Dense
model.compile(optimizer='adam', loss='mse')

model.summary()
# Out:
# 2024-03-26 04:14:17.763774: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-03-26 04:14:18.114752: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-03-26 04:14:18.370436: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-26 04:14:19.352481: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /opt/conda/envs/ts/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 30, 64)         │        16,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 30, 1)          │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 16,961 (66.25 KB)
#  Trainable params: 16,961 (66.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Fit the model
history = model.fit(X_train, y_train, epochs=200, batch_size=64, verbose=1, shuffle=False, validation_data=(X_test, y_test))
# Out:
# Epoch 1/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - loss: 1120.5829 - val_loss: 1179.5834
# Epoch 2/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 853.5076 - val_loss: 994.0002
# Epoch 3/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 717.6922 - val_loss: 905.9692
# Epoch 4/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 651.9899 - val_loss: 855.7250
# Epoch 5/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 611.4421 - val_loss: 801.9146
# Epoch 6/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 570.2593 - val_loss: 754.9000
# Epoch 7/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 532.9736 - val_loss: 715.7898
# Epoch 8/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 502.6800 - val_loss: 682.8559
# Epoch 9/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 476.3511 - val_loss: 653.1988
# Epoch 10/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 452.5977 - val_loss: 626.4441
# Epoch 11/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 431.3263 - val_loss: 602.0629
# Epoch 12/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 412.0052 - val_loss: 578.7977
# Epoch 13/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 393.3435 - val_loss: 557.1684
# Epoch 14/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 376.4015 - val_loss: 536.9379
# Epoch 15/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 361.0028 - val_loss: 519.4694
# Epoch 16/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 347.3223 - val_loss: 503.0037
# Epoch 17/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 334.8189 - val_loss: 488.0337
# Epoch 18/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 323.3483 - val_loss: 474.0511
# Epoch 19/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 312.9510 - val_loss: 460.1742
# Epoch 20/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 301.9315 - val_loss: 446.4294
# Epoch 21/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 292.1535 - val_loss: 434.6512
# Epoch 22/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 283.4435 - val_loss: 423.5284
# Epoch 23/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 275.4544 - val_loss: 413.1526
# Epoch 24/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 267.9601 - val_loss: 403.4077
# Epoch 25/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 261.0231 - val_loss: 394.3450
# Epoch 26/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 256.2774 - val_loss: 385.5720
# Epoch 27/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 248.4902 - val_loss: 377.5016
# Epoch 28/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 242.6635 - val_loss: 369.7277
# Epoch 29/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 237.2734 - val_loss: 362.2751
# Epoch 30/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 232.2291 - val_loss: 355.0758
# Epoch 31/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 227.3891 - val_loss: 348.1549
# Epoch 32/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 223.0793 - val_loss: 341.5196
# Epoch 33/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 218.5068 - val_loss: 335.1553
# Epoch 34/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 214.4868 - val_loss: 328.8731
# Epoch 35/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 210.5469 - val_loss: 322.9731
# Epoch 36/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 206.8296 - val_loss: 316.9191
# Epoch 37/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 203.2470 - val_loss: 311.5022
# Epoch 38/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 199.6922 - val_loss: 305.9825
# Epoch 39/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 196.5258 - val_loss: 300.4467
# Epoch 40/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 193.3225 - val_loss: 295.3752
# Epoch 41/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 190.3530 - val_loss: 290.3698
# Epoch 42/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 187.5327 - val_loss: 285.3553
# Epoch 43/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 184.8125 - val_loss: 280.7278
# Epoch 44/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 182.3160 - val_loss: 275.9681
# Epoch 45/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 179.7794 - val_loss: 272.0956
# Epoch 46/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 177.2979 - val_loss: 267.5049
# Epoch 47/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 175.1056 - val_loss: 263.4938
# Epoch 48/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 172.9408 - val_loss: 259.4578
# Epoch 49/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 170.9083 - val_loss: 255.8711
# Epoch 50/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 168.6838 - val_loss: 251.8914
# Epoch 51/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 166.8157 - val_loss: 248.0743
# Epoch 52/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 164.8898 - val_loss: 244.0298
# Epoch 53/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 162.8715 - val_loss: 240.3955
# Epoch 54/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 160.9917 - val_loss: 237.0191
# Epoch 55/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 159.2417 - val_loss: 233.6390
# Epoch 56/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 157.5610 - val_loss: 230.6228
# Epoch 57/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 156.0383 - val_loss: 227.3176
# Epoch 58/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 154.6180 - val_loss: 224.4221
# Epoch 59/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 153.1212 - val_loss: 221.5350
# Epoch 60/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 151.8182 - val_loss: 218.6806
# Epoch 61/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 150.3788 - val_loss: 216.2090
# Epoch 62/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 149.1562 - val_loss: 213.4569
# Epoch 63/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 147.8668 - val_loss: 210.8431
# Epoch 64/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 146.6995 - val_loss: 208.7122
# Epoch 65/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 145.7330 - val_loss: 205.9763
# Epoch 66/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 144.4773 - val_loss: 203.6685
# Epoch 67/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 143.4249 - val_loss: 201.3721
# Epoch 68/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 142.4031 - val_loss: 199.2852
# Epoch 69/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 141.4063 - val_loss: 197.1851
# Epoch 70/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 140.5124 - val_loss: 195.1558
# Epoch 71/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 139.5621 - val_loss: 193.2162
# Epoch 72/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 138.7076 - val_loss: 191.3441
# Epoch 73/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 137.8754 - val_loss: 189.5220
# Epoch 74/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 137.0772 - val_loss: 187.7514
# Epoch 75/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 136.3131 - val_loss: 186.0400
# Epoch 76/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 135.5783 - val_loss: 184.3801
# Epoch 77/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 134.8658 - val_loss: 182.7854
# Epoch 78/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 134.1817 - val_loss: 181.2676
# Epoch 79/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 133.5592 - val_loss: 179.7230
# Epoch 80/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 132.9168 - val_loss: 178.3595
# Epoch 81/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 132.4668 - val_loss: 176.8506
# Epoch 82/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 131.9008 - val_loss: 175.5142
# Epoch 83/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 131.3273 - val_loss: 174.1716
# Epoch 84/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 130.7822 - val_loss: 172.8980
# Epoch 85/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 130.2374 - val_loss: 171.7283
# Epoch 86/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 129.9285 - val_loss: 170.4609
# Epoch 87/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 129.4040 - val_loss: 169.1937
# Epoch 88/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 128.9172 - val_loss: 168.0860
# Epoch 89/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 128.4288 - val_loss: 166.9349
# Epoch 90/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 127.9775 - val_loss: 165.8017
# Epoch 91/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 127.5678 - val_loss: 164.9180
# Epoch 92/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 127.4660 - val_loss: 163.5833
# Epoch 93/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 126.8134 - val_loss: 162.5889
# Epoch 94/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 126.3536 - val_loss: 161.6300
# Epoch 95/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 125.9469 - val_loss: 160.6298
# Epoch 96/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 125.5221 - val_loss: 159.6355
# Epoch 97/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 125.1005 - val_loss: 158.6963
# Epoch 98/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 124.7075 - val_loss: 157.8511
# Epoch 99/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 124.3507 - val_loss: 156.9693
# Epoch 100/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 124.0480 - val_loss: 156.0707
# Epoch 101/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 123.6342 - val_loss: 155.1335
# Epoch 102/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 123.2281 - val_loss: 154.1282
# Epoch 103/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 122.8782 - val_loss: 153.5771
# Epoch 104/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 122.6902 - val_loss: 152.5705
# Epoch 105/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 122.2474 - val_loss: 152.1673
# Epoch 106/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 122.0641 - val_loss: 151.1046
# Epoch 107/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 121.5547 - val_loss: 150.5943
# Epoch 108/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 121.2040 - val_loss: 149.5644
# Epoch 109/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 121.0389 - val_loss: 148.7853
# Epoch 110/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 120.6819 - val_loss: 148.2108
# Epoch 111/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 120.3032 - val_loss: 147.8507
# Epoch 112/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 120.0295 - val_loss: 147.3732
# Epoch 113/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 119.6255 - val_loss: 146.6578
# Epoch 114/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 119.3927 - val_loss: 145.8228
# Epoch 115/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 118.9428 - val_loss: 145.3755
# Epoch 116/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 118.6882 - val_loss: 144.4619
# Epoch 117/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 118.3547 - val_loss: 143.7595
# Epoch 118/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 118.2172 - val_loss: 143.5120
# Epoch 119/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 117.7582 - val_loss: 143.0585
# Epoch 120/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 117.5711 - val_loss: 142.4439
# Epoch 121/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 117.2131 - val_loss: 141.9629
# Epoch 122/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 116.9936 - val_loss: 141.4659
# Epoch 123/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 116.6982 - val_loss: 140.8519
# Epoch 124/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 116.3650 - val_loss: 140.3038
# Epoch 125/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 116.0381 - val_loss: 139.7744
# Epoch 126/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 115.7918 - val_loss: 139.3730
# Epoch 127/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 115.4909 - val_loss: 138.8867
# Epoch 128/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 115.2882 - val_loss: 138.6856
# Epoch 129/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 115.0309 - val_loss: 138.1116
# Epoch 130/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 114.8117 - val_loss: 137.7547
# Epoch 131/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 114.5269 - val_loss: 137.3158
# Epoch 132/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 114.2296 - val_loss: 136.7916
# Epoch 133/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 114.1112 - val_loss: 136.3491
# Epoch 134/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 113.8267 - val_loss: 135.9495
# Epoch 135/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 114.6831 - val_loss: 140.0004
# Epoch 136/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 114.7238 - val_loss: 138.9513
# Epoch 137/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 114.4173 - val_loss: 138.6882
# Epoch 138/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 113.8659 - val_loss: 138.3857
# Epoch 139/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 113.5581 - val_loss: 137.9787
# Epoch 140/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 113.2975 - val_loss: 137.5329
# Epoch 141/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 112.9624 - val_loss: 136.3436
# Epoch 142/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 112.8098 - val_loss: 132.5784
# Epoch 143/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 112.4003 - val_loss: 135.8292
# Epoch 144/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 112.4444 - val_loss: 134.0020
# Epoch 145/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 111.8594 - val_loss: 132.9769
# Epoch 146/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 112.0876 - val_loss: 131.1917
# Epoch 147/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 111.4037 - val_loss: 131.6826
# Epoch 148/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 111.9622 - val_loss: 130.8463
# Epoch 149/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 110.8677 - val_loss: 131.2657
# Epoch 150/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 110.4670 - val_loss: 131.0658
# Epoch 151/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 110.2568 - val_loss: 130.4380
# Epoch 152/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 110.1569 - val_loss: 130.1076
# Epoch 153/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 109.7463 - val_loss: 130.0804
# Epoch 154/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 109.6265 - val_loss: 129.3899
# Epoch 155/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 109.3592 - val_loss: 129.4807
# Epoch 156/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 109.4293 - val_loss: 128.8512
# Epoch 157/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 109.1598 - val_loss: 129.0914
# Epoch 158/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 109.2115 - val_loss: 128.3007
# Epoch 159/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 108.7252 - val_loss: 128.9377
# Epoch 160/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 108.3434 - val_loss: 128.0285
# Epoch 161/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 108.1296 - val_loss: 128.3261
# Epoch 162/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 107.8408 - val_loss: 127.6846
# Epoch 163/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 107.7086 - val_loss: 127.9940
# Epoch 164/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 107.3725 - val_loss: 127.4141
# Epoch 165/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 107.2438 - val_loss: 127.5659
# Epoch 166/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 106.9708 - val_loss: 127.4786
# Epoch 167/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 106.7863 - val_loss: 127.1576
# Epoch 168/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 106.6475 - val_loss: 127.6633
# Epoch 169/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 106.4099 - val_loss: 127.0756
# Epoch 170/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 106.3420 - val_loss: 127.4653
# Epoch 171/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 106.3615 - val_loss: 126.4414
# Epoch 172/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 106.5561 - val_loss: 126.3071
# Epoch 173/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 106.2626 - val_loss: 126.0892
# Epoch 174/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 105.8893 - val_loss: 126.9695
# Epoch 175/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 105.3752 - val_loss: 126.6936
# Epoch 176/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 105.3952 - val_loss: 126.3482
# Epoch 177/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 105.1713 - val_loss: 126.5510
# Epoch 178/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 104.8654 - val_loss: 125.9026
# Epoch 179/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 104.7266 - val_loss: 124.6035
# Epoch 180/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 104.5793 - val_loss: 125.4337
# Epoch 181/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 104.0365 - val_loss: 125.1686
# Epoch 182/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 103.9482 - val_loss: 124.7526
# Epoch 183/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 103.7526 - val_loss: 124.6180
# Epoch 184/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 103.5280 - val_loss: 124.4907
# Epoch 185/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 103.1599 - val_loss: 124.6765
# Epoch 186/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 103.1144 - val_loss: 124.2841
# Epoch 187/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 102.9181 - val_loss: 124.3798
# Epoch 188/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 103.1868 - val_loss: 124.1636
# Epoch 189/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 102.7031 - val_loss: 124.7933
# Epoch 190/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 103.4053 - val_loss: 124.0078
# Epoch 191/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 103.7159 - val_loss: 127.1151
# Epoch 192/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 103.9100 - val_loss: 125.2394
# Epoch 193/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 102.2259 - val_loss: 124.9631
# Epoch 194/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 101.8909 - val_loss: 123.5616
# Epoch 195/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 101.8803 - val_loss: 123.8530
# Epoch 196/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 101.3202 - val_loss: 121.9069
# Epoch 197/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 101.8155 - val_loss: 122.2732
# Epoch 198/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 100.5665 - val_loss: 122.3113
# Epoch 199/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 99.8929 - val_loss: 122.2484
# Epoch 200/200
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 99.8277 - val_loss: 122.2030

# %%
# display loss
plt.figure(figsize=(10,5))
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
X_test.shape ,y_test.shape
# Out:
# ((700, 30, 1), (700, 30, 1))

# %%
# make a full prediction on the test data, then plot the result on dataframe

# %%
# make a prediction and evaluuate
y_pred = model.predict(X_test[-1].reshape(1, next_t, 1))
# reshape the data
y_pred = y_pred.reshape(-1, 1)
print(y_pred.shape)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# (30, 1)

# %%
# Last date of the test data
last_date = test['Date'].values[-1]

# Create the next 30 days date range
next_t = 30
next_t_days = pd.date_range(last_date, periods=next_t)

# Concatenate the last 30 days and the next 30 days into a new dataframe named big_df based on random_df_copy
big_df = random_df_copy.copy()
predicted_values_df = pd.DataFrame({'Date': next_t_days, '36T': None})
big_df = pd.concat([big_df, predicted_values_df], ignore_index=True)

big_df.tail()
# Out:
# /tmp/ipykernel_44602/3019929442.py:11: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   big_df = pd.concat([big_df, predicted_values_df], ignore_index=True)
#            Date  36T
# 4772 2024-01-25  NaN
# 4773 2024-01-26  NaN
# 4774 2024-01-27  NaN
# 4775 2024-01-28  NaN
# 4776 2024-01-29  NaN

# %%
import datetime
# Calculate the date 2 years ago from the current date
two_years_ago = datetime.datetime.now() - datetime.timedelta(days=365*2)

# Filter the dataframe based on the date range
filtered_df = big_df[big_df['Date'] >= two_years_ago]

# Plot the filtered dataframe
plt.figure(figsize=(10,5))
plt.plot(filtered_df['Date'], filtered_df['36T'], label='Actual')
# plot on predicted values
plt.plot(next_t_days, y_pred, label='Predictions')
plt.legend()
plt.show()
